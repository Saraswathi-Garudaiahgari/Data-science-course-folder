# %% [markdown]
# # My Jupyter Notebook on IBM Watson studio.

# %% [markdown]
# My name is Saraswathi Garudaiahgari and I am a student.

# %% [markdown]
# *I want to learn how to analyse data and draw useful conclusion from it.*

# %% [markdown]
# ### A simple function to calculate square of a given number.

# %%
def square(num):
    a = num *num
    return a
square(3)
square(12)
# Out:
# 144

# %% [markdown]
# ### numbered list.
# 1. One
# 2. Two
# 3. three

# %% [markdown]
# ### Blocked quotes.
#
# > Pandas and Numpy are most used libraries in Data Science.<b>

# %% [markdown]
# ### Hyper links.
# Best online courses are found [clik](https://www.coursera.org/?skipBrowseRedirect=true)
